# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns



# Activation Functions

# fonction ReLU
def relu(x):
    """
    ReLU activation: max(0, x)
    """
    assert isinstance(x, np.ndarray), "Input to ReLU must be a numpy array"
    result = np.maximum(0, x)
    assert np.all(result >= 0), "ReLU output must be non-negative"
    return result

# fonction relu_derivative
def relu_derivative(x):
    """
    Derivative of ReLU: 1 if x > 0, else 0
    """
    assert isinstance(x, np.ndarray), "Input to ReLU derivative must be a numpy array"
    result = np.where(x > 0, 1, 0)
    assert np.all((result == 0) | (result == 1)), "ReLU derivative must be 0 or 1"
    return result


# fonction sigmoid
def sigmoid(x):
    """
    Sigmoid activation: 1 / (1 + exp(-x))
    """
    assert isinstance(x, np.ndarray), "Input to sigmoid must be a numpy array"
    # Clip x to avoid overflow in exp(-x) for large negative x
    # and underflow (exp(-x) -> inf) for large positive x.
    # Also avoids log(0) in loss calculation later.
    clipped_x = np.clip(x, -500, 500)
    result = 1 / (1 + np.exp(-clipped_x))
    # Add small epsilon to avoid exact 0 or 1 for log calculation stability
    epsilon = 1e-15
    result = np.clip(result, epsilon, 1 - epsilon)
    assert np.all((result >= 0) & (result <= 1)), "Sigmoid output must be in [0, 1]"
    return result


# fonction sigmoid_derivative
def sigmoid_derivative(x):
    """
    Derivative of sigmoid: sigmoid(x) * (1 - sigmoid(x))
    """
    assert isinstance(x, np.ndarray), "Input to sigmoid derivative must be a numpy array"
    s = sigmoid(x)
    result = s * (1 - s)
    # The theoretical max is 0.25, but due to epsilon clipping in sigmoid, 
    # we might be slightly off. Check within a tolerance.
    assert np.all((result >= 0) & (result <= 0.25 + 1e-9)), "Sigmoid derivative must be in [0, 0.25]"
    return result



# Neural Network class
class NeuralNetwork:
    def __init__(self, layer_sizes, learning_rate=0.01, l2_lambda=0.01):
        """Initialize the neural network with given layer sizes, learning rate, and L2 regularization."""
        self.layer_sizes = layer_sizes
        self.learning_rate = learning_rate
        self.l2_lambda = l2_lambda
        self.weights = []
        self.biases = []
        np.random.seed(42)
        for i in range(len(layer_sizes) - 1):
            w = np.random.randn(layer_sizes[i], layer_sizes[i + 1]) * 0.01
            b = np.zeros((1, layer_sizes[i + 1]))
            self.weights.append(w)
            self.biases.append(b)

    def forward(self, X):
        """Forward propagation: compute activations for all layers."""
        self.activations = [X]
        self.z_values = []
        for i in range(len(self.weights) - 1):
            z = np.dot(self.activations[-1], self.weights[i]) + self.biases[i]
            self.z_values.append(z)
            self.activations.append(relu(z))
        z = np.dot(self.activations[-1], self.weights[-1]) + self.biases[-1]
        self.z_values.append(z)
        output = sigmoid(z)
        self.activations.append(output)
        return output

    def compute_loss(self, y_true, y_pred):
        """Binary Cross-Entropy loss with L2 regularization."""
        m = y_true.shape[0]
        y_pred = np.clip(y_pred, 1e-15, 1 - 1e-15)  # Avoid log(0)
        loss = -np.mean(y_true * np.log(y_pred) + (1 - y_true) * np.log(1 - y_pred))
        # Add L2 regularization
        l2_term = self.l2_lambda * sum(np.sum(w ** 2) for w in self.weights) / (2 * m)
        return loss + l2_term

    def compute_accuracy(self, y_true, y_pred):
        """Compute accuracy: proportion of correct predictions."""
        predictions = (y_pred >= 0.5).astype(int)
        return np.mean(predictions == y_true)

    def backward(self, X, y, outputs):
        """Backpropagation: compute gradients with L2 regularization."""
        m = X.shape[0]
        self.d_weights = [np.zeros_like(w) for w in self.weights]
        self.d_biases = [np.zeros_like(b) for b in self.biases]
        dZ = outputs - y
        self.d_weights[-1] = (np.dot(self.activations[-2].T, dZ) + self.l2_lambda * self.weights[-1]) / m
        self.d_biases[-1] = np.sum(dZ, axis=0, keepdims=True) / m
        for i in range(len(self.weights) - 2, -1, -1):
            dA = np.dot(dZ, self.weights[i + 1].T)
            dZ = dA * relu_derivative(self.z_values[i])
            self.d_weights[i] = (np.dot(self.activations[i].T, dZ) + self.l2_lambda * self.weights[i]) / m
            self.d_biases[i] = np.sum(dZ, axis=0, keepdims=True) / m
        for i in range(len(self.weights)):
            self.weights[i] -= self.learning_rate * self.d_weights[i]
            self.biases[i] -= self.learning_rate * self.d_biases[i]

    def train(self, X, y, X_val, y_val, epochs, batch_size):
        """Train the neural network using mini-batch SGD with validation."""
        train_losses = []
        val_losses = []
        train_accuracies = []
        val_accuracies = []
        for epoch in range(epochs):
            indices = np.random.permutation(X.shape[0])
            X_shuffled = X[indices]
            y_shuffled = y[indices]
            epoch_loss = 0
            for i in range(0, X.shape[0], batch_size):
                X_batch = X_shuffled[i:i + batch_size]
                y_batch = y_shuffled[i:i + batch_size]
                outputs = self.forward(X_batch)
                epoch_loss += self.compute_loss(y_batch, outputs)
                self.backward(X_batch, y_batch, outputs)
            epoch_loss /= (X.shape[0] / batch_size)
            train_loss = self.compute_loss(y, self.forward(X))
            val_loss = self.compute_loss(y_val, self.forward(X_val))
            train_accuracy = self.compute_accuracy(y, self.forward(X))
            val_accuracy = self.compute_accuracy(y_val, self.forward(X_val))
            train_losses.append(train_loss)
            val_losses.append(val_loss)
            train_accuracies.append(train_accuracy)
            val_accuracies.append(val_accuracy)
            if epoch % 10 == 0:
                print(f"Epoch {epoch}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, Train Acc: {train_accuracy:.4f}, Val Acc: {val_accuracy:.4f}")
        return train_losses, val_losses, train_accuracies, val_accuracies

    def predict(self, X):
        """Predict class labels (0 or 1)."""
        outputs = self.forward(X)
        return (outputs >= 0.5).astype(int)

# Data preprocessing and training

# Load dataset
data = pd.read_csv('diabetes.csv')

# Replace invalid zeros with median
for col in ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']:
    data[col] = data[col].replace(0, data[col].median())

    
# Features and target
X = data.drop('Outcome', axis=1).values
y = data['Outcome'].values.reshape(-1, 1)

    
# Standardize features
X = (X - np.mean(X, axis=0)) / np.std(X, axis=0)
 
# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# Initialize and train model
nn = NeuralNetwork([X_train.shape[1], 16, 8, 1], learning_rate=0.01, l2_lambda=0.01)
train_losses, val_losses, train_accuracies, val_accuracies = nn.train(X_train, y_train, X_test, y_test, epochs=1500, batch_size=32)

# Evaluate
y_pred = nn.predict(X_test)
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

    # Confusion matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
    
# Loss and accuracy curves
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
ax1.plot(train_losses, label='Train Loss')
ax1.plot(val_losses, label='Validation Loss')
ax1.set_title('Loss Curves')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()
ax2.plot(train_accuracies, label='Train Accuracy')
ax2.plot(val_accuracies, label='Validation Accuracy')
ax2.set_title('Accuracy Curves')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.legend()
plt.show()
# Out:
# Epoch 0, Train Loss: 0.6893, Val Loss: 0.6894, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 10, Train Loss: 0.6630, Val Loss: 0.6636, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 20, Train Loss: 0.6528, Val Loss: 0.6537, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 30, Train Loss: 0.6490, Val Loss: 0.6500, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 40, Train Loss: 0.6473, Val Loss: 0.6485, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 50, Train Loss: 0.6470, Val Loss: 0.6482, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 60, Train Loss: 0.6467, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 70, Train Loss: 0.6466, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 80, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 90, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 100, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 110, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 120, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 130, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 140, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 150, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 160, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 170, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 180, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 190, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 200, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 210, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 220, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 230, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 240, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 250, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 260, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 270, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 280, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 290, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 300, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 310, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 320, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 330, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 340, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 350, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 360, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 370, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 380, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 390, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 400, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 410, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 420, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 430, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 440, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 450, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 460, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 470, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 480, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 490, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 500, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 510, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 520, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 530, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 540, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 550, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 560, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 570, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 580, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 590, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 600, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 610, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 620, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 630, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 640, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 650, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 660, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 670, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 680, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 690, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 700, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 710, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 720, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 730, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 740, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 750, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 760, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 770, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 780, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 790, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 800, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 810, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 820, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 830, Train Loss: 0.6464, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 840, Train Loss: 0.6464, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 850, Train Loss: 0.6464, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 860, Train Loss: 0.6464, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 870, Train Loss: 0.6464, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 880, Train Loss: 0.6464, Val Loss: 0.6477, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 890, Train Loss: 0.6464, Val Loss: 0.6477, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 900, Train Loss: 0.6463, Val Loss: 0.6477, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 910, Train Loss: 0.6463, Val Loss: 0.6477, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 920, Train Loss: 0.6463, Val Loss: 0.6477, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 930, Train Loss: 0.6462, Val Loss: 0.6476, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 940, Train Loss: 0.6462, Val Loss: 0.6476, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 950, Train Loss: 0.6462, Val Loss: 0.6476, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 960, Train Loss: 0.6461, Val Loss: 0.6475, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 970, Train Loss: 0.6460, Val Loss: 0.6474, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 980, Train Loss: 0.6459, Val Loss: 0.6474, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 990, Train Loss: 0.6458, Val Loss: 0.6473, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 1000, Train Loss: 0.6457, Val Loss: 0.6471, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 1010, Train Loss: 0.6455, Val Loss: 0.6470, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 1020, Train Loss: 0.6452, Val Loss: 0.6468, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 1030, Train Loss: 0.6449, Val Loss: 0.6465, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 1040, Train Loss: 0.6444, Val Loss: 0.6461, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 1050, Train Loss: 0.6438, Val Loss: 0.6456, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 1060, Train Loss: 0.6429, Val Loss: 0.6449, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 1070, Train Loss: 0.6416, Val Loss: 0.6438, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 1080, Train Loss: 0.6398, Val Loss: 0.6423, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 1090, Train Loss: 0.6368, Val Loss: 0.6398, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 1100, Train Loss: 0.6320, Val Loss: 0.6358, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 1110, Train Loss: 0.6239, Val Loss: 0.6291, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 1120, Train Loss: 0.6103, Val Loss: 0.6182, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 1130, Train Loss: 0.5874, Val Loss: 0.6002, Train Acc: 0.6498, Val Acc: 0.6558
# Epoch 1140, Train Loss: 0.5534, Val Loss: 0.5751, Train Acc: 0.7345, Val Acc: 0.7013
# Epoch 1150, Train Loss: 0.5166, Val Loss: 0.5511, Train Acc: 0.7720, Val Acc: 0.7208
# Epoch 1160, Train Loss: 0.4891, Val Loss: 0.5363, Train Acc: 0.7752, Val Acc: 0.7273
# Epoch 1170, Train Loss: 0.4718, Val Loss: 0.5306, Train Acc: 0.7801, Val Acc: 0.7143
# Epoch 1180, Train Loss: 0.4614, Val Loss: 0.5281, Train Acc: 0.7850, Val Acc: 0.7143
# Epoch 1190, Train Loss: 0.4551, Val Loss: 0.5252, Train Acc: 0.7915, Val Acc: 0.6948
# Epoch 1200, Train Loss: 0.4503, Val Loss: 0.5248, Train Acc: 0.7932, Val Acc: 0.6883
# Epoch 1210, Train Loss: 0.4467, Val Loss: 0.5233, Train Acc: 0.7850, Val Acc: 0.6883
# Epoch 1220, Train Loss: 0.4442, Val Loss: 0.5244, Train Acc: 0.7866, Val Acc: 0.7013
# Epoch 1230, Train Loss: 0.4422, Val Loss: 0.5228, Train Acc: 0.7932, Val Acc: 0.6948
# Epoch 1240, Train Loss: 0.4405, Val Loss: 0.5242, Train Acc: 0.7948, Val Acc: 0.6948
# Epoch 1250, Train Loss: 0.4393, Val Loss: 0.5242, Train Acc: 0.7932, Val Acc: 0.7013
# Epoch 1260, Train Loss: 0.4382, Val Loss: 0.5239, Train Acc: 0.7899, Val Acc: 0.6948
# Epoch 1270, Train Loss: 0.4372, Val Loss: 0.5236, Train Acc: 0.7899, Val Acc: 0.6948
# Epoch 1280, Train Loss: 0.4364, Val Loss: 0.5249, Train Acc: 0.7883, Val Acc: 0.7013
# Epoch 1290, Train Loss: 0.4354, Val Loss: 0.5253, Train Acc: 0.7850, Val Acc: 0.6948
# Epoch 1300, Train Loss: 0.4346, Val Loss: 0.5248, Train Acc: 0.7834, Val Acc: 0.7013
# Epoch 1310, Train Loss: 0.4337, Val Loss: 0.5241, Train Acc: 0.7883, Val Acc: 0.6948
# Epoch 1320, Train Loss: 0.4328, Val Loss: 0.5243, Train Acc: 0.7850, Val Acc: 0.6948
# Epoch 1330, Train Loss: 0.4320, Val Loss: 0.5268, Train Acc: 0.7834, Val Acc: 0.6948
# Epoch 1340, Train Loss: 0.4312, Val Loss: 0.5282, Train Acc: 0.7850, Val Acc: 0.6948
# Epoch 1350, Train Loss: 0.4305, Val Loss: 0.5295, Train Acc: 0.7866, Val Acc: 0.6948
# Epoch 1360, Train Loss: 0.4299, Val Loss: 0.5270, Train Acc: 0.7866, Val Acc: 0.6948
# Epoch 1370, Train Loss: 0.4293, Val Loss: 0.5288, Train Acc: 0.7850, Val Acc: 0.7013
# Epoch 1380, Train Loss: 0.4286, Val Loss: 0.5310, Train Acc: 0.7883, Val Acc: 0.6948
# Epoch 1390, Train Loss: 0.4279, Val Loss: 0.5293, Train Acc: 0.7866, Val Acc: 0.6948
# Epoch 1400, Train Loss: 0.4271, Val Loss: 0.5305, Train Acc: 0.7866, Val Acc: 0.7013
# Epoch 1410, Train Loss: 0.4267, Val Loss: 0.5280, Train Acc: 0.7850, Val Acc: 0.6948
# Epoch 1420, Train Loss: 0.4259, Val Loss: 0.5289, Train Acc: 0.7866, Val Acc: 0.7013
# Epoch 1430, Train Loss: 0.4252, Val Loss: 0.5289, Train Acc: 0.7850, Val Acc: 0.7013
# Epoch 1440, Train Loss: 0.4246, Val Loss: 0.5287, Train Acc: 0.7915, Val Acc: 0.7013
# Epoch 1450, Train Loss: 0.4240, Val Loss: 0.5287, Train Acc: 0.7883, Val Acc: 0.7078
# Epoch 1460, Train Loss: 0.4235, Val Loss: 0.5294, Train Acc: 0.7883, Val Acc: 0.7013
# Epoch 1470, Train Loss: 0.4229, Val Loss: 0.5315, Train Acc: 0.7899, Val Acc: 0.6948
# Epoch 1480, Train Loss: 0.4224, Val Loss: 0.5320, Train Acc: 0.7899, Val Acc: 0.6948
# Epoch 1490, Train Loss: 0.4218, Val Loss: 0.5289, Train Acc: 0.7948, Val Acc: 0.7013
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.80      0.78       100
#            1       0.58      0.52      0.55        54
#
#     accuracy                           0.70       154
#    macro avg       0.67      0.66      0.66       154
# weighted avg       0.69      0.70      0.70       154

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns



# Activation Functions

# fonction ReLU
def relu(x):
    """
    ReLU activation: max(0, x)
    """
    assert isinstance(x, np.ndarray), "Input to ReLU must be a numpy array"
    result = np.maximum(0, x)
    assert np.all(result >= 0), "ReLU output must be non-negative"
    return result

# fonction relu_derivative
def relu_derivative(x):
    """
    Derivative of ReLU: 1 if x > 0, else 0
    """
    assert isinstance(x, np.ndarray), "Input to ReLU derivative must be a numpy array"
    result = np.where(x > 0, 1, 0)
    assert np.all((result == 0) | (result == 1)), "ReLU derivative must be 0 or 1"
    return result


# fonction sigmoid
def sigmoid(x):
    """
    Sigmoid activation: 1 / (1 + exp(-x))
    """
    assert isinstance(x, np.ndarray), "Input to sigmoid must be a numpy array"
    # Clip x to avoid overflow in exp(-x) for large negative x
    # and underflow (exp(-x) -> inf) for large positive x.
    # Also avoids log(0) in loss calculation later.
    clipped_x = np.clip(x, -500, 500)
    result = 1 / (1 + np.exp(-clipped_x))
    # Add small epsilon to avoid exact 0 or 1 for log calculation stability
    epsilon = 1e-15
    result = np.clip(result, epsilon, 1 - epsilon)
    assert np.all((result >= 0) & (result <= 1)), "Sigmoid output must be in [0, 1]"
    return result


# fonction sigmoid_derivative
def sigmoid_derivative(x):
    """
    Derivative of sigmoid: sigmoid(x) * (1 - sigmoid(x))
    """
    assert isinstance(x, np.ndarray), "Input to sigmoid derivative must be a numpy array"
    s = sigmoid(x)
    result = s * (1 - s)
    # The theoretical max is 0.25, but due to epsilon clipping in sigmoid, 
    # we might be slightly off. Check within a tolerance.
    assert np.all((result >= 0) & (result <= 0.25 + 1e-9)), "Sigmoid derivative must be in [0, 0.25]"
    return result



# Neural Network class
class NeuralNetwork:
    def __init__(self, layer_sizes, learning_rate=0.01, l2_lambda=0.01):
        """Initialize the neural network with given layer sizes, learning rate, and L2 regularization."""
        self.layer_sizes = layer_sizes
        self.learning_rate = learning_rate
        self.l2_lambda = l2_lambda
        self.weights = []
        self.biases = []
        np.random.seed(42)
        for i in range(len(layer_sizes) - 1):
            w = np.random.randn(layer_sizes[i], layer_sizes[i + 1]) * 0.01
            b = np.zeros((1, layer_sizes[i + 1]))
            self.weights.append(w)
            self.biases.append(b)

    def forward(self, X):
        """Forward propagation: compute activations for all layers."""
        self.activations = [X]
        self.z_values = []
        for i in range(len(self.weights) - 1):
            z = np.dot(self.activations[-1], self.weights[i]) + self.biases[i]
            self.z_values.append(z)
            self.activations.append(relu(z))
        z = np.dot(self.activations[-1], self.weights[-1]) + self.biases[-1]
        self.z_values.append(z)
        output = sigmoid(z)
        self.activations.append(output)
        return output

    def compute_loss(self, y_true, y_pred):
        """Binary Cross-Entropy loss with L2 regularization."""
        m = y_true.shape[0]
        y_pred = np.clip(y_pred, 1e-15, 1 - 1e-15)  # Avoid log(0)
        loss = -np.mean(y_true * np.log(y_pred) + (1 - y_true) * np.log(1 - y_pred))
        # Add L2 regularization
        l2_term = self.l2_lambda * sum(np.sum(w ** 2) for w in self.weights) / (2 * m)
        return loss + l2_term

    def compute_accuracy(self, y_true, y_pred):
        """Compute accuracy: proportion of correct predictions."""
        predictions = (y_pred >= 0.5).astype(int)
        return np.mean(predictions == y_true)

    def backward(self, X, y, outputs):
        """Backpropagation: compute gradients with L2 regularization."""
        m = X.shape[0]
        self.d_weights = [np.zeros_like(w) for w in self.weights]
        self.d_biases = [np.zeros_like(b) for b in self.biases]
        dZ = outputs - y
        self.d_weights[-1] = (np.dot(self.activations[-2].T, dZ) + self.l2_lambda * self.weights[-1]) / m
        self.d_biases[-1] = np.sum(dZ, axis=0, keepdims=True) / m
        for i in range(len(self.weights) - 2, -1, -1):
            dA = np.dot(dZ, self.weights[i + 1].T)
            dZ = dA * relu_derivative(self.z_values[i])
            self.d_weights[i] = (np.dot(self.activations[i].T, dZ) + self.l2_lambda * self.weights[i]) / m
            self.d_biases[i] = np.sum(dZ, axis=0, keepdims=True) / m
        for i in range(len(self.weights)):
            self.weights[i] -= self.learning_rate * self.d_weights[i]
            self.biases[i] -= self.learning_rate * self.d_biases[i]

    def train(self, X, y, X_val, y_val, epochs, batch_size):
        """Train the neural network using mini-batch SGD with validation."""
        train_losses = []
        val_losses = []
        train_accuracies = []
        val_accuracies = []
        for epoch in range(epochs):
            indices = np.random.permutation(X.shape[0])
            X_shuffled = X[indices]
            y_shuffled = y[indices]
            epoch_loss = 0
            for i in range(0, X.shape[0], batch_size):
                X_batch = X_shuffled[i:i + batch_size]
                y_batch = y_shuffled[i:i + batch_size]
                outputs = self.forward(X_batch)
                epoch_loss += self.compute_loss(y_batch, outputs)
                self.backward(X_batch, y_batch, outputs)
            epoch_loss /= (X.shape[0] / batch_size)
            train_loss = self.compute_loss(y, self.forward(X))
            val_loss = self.compute_loss(y_val, self.forward(X_val))
            train_accuracy = self.compute_accuracy(y, self.forward(X))
            val_accuracy = self.compute_accuracy(y_val, self.forward(X_val))
            train_losses.append(train_loss)
            val_losses.append(val_loss)
            train_accuracies.append(train_accuracy)
            val_accuracies.append(val_accuracy)
            if epoch % 10 == 0:
                print(f"Epoch {epoch}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, Train Acc: {train_accuracy:.4f}, Val Acc: {val_accuracy:.4f}")
        return train_losses, val_losses, train_accuracies, val_accuracies

    def predict(self, X):
        """Predict class labels (0 or 1)."""
        outputs = self.forward(X)
        return (outputs >= 0.5).astype(int)

# Data preprocessing and training

# Load dataset
data = pd.read_csv('diabetes.csv')

# Replace invalid zeros with median
for col in ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']:
    data[col] = data[col].replace(0, data[col].median())

    
# Features and target
X = data.drop('Outcome', axis=1).values
y = data['Outcome'].values.reshape(-1, 1)

    
# Standardize features
X = (X - np.mean(X, axis=0)) / np.std(X, axis=0)
 
# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# Initialize and train model
nn = NeuralNetwork([X_train.shape[1], 16, 8, 1], learning_rate=0.01, l2_lambda=0.01)
train_losses, val_losses, train_accuracies, val_accuracies = nn.train(X_train, y_train, X_test, y_test, epochs=100, batch_size=32)

# Evaluate
y_pred = nn.predict(X_test)
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
    # Confusion matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
    
# Loss and accuracy curves
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
ax1.plot(train_losses, label='Train Loss')
ax1.plot(val_losses, label='Validation Loss')
ax1.set_title('Loss Curves')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()
ax2.plot(train_accuracies, label='Train Accuracy')
ax2.plot(val_accuracies, label='Validation Accuracy')
ax2.set_title('Accuracy Curves')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.legend()
plt.show()
# Out:
# Epoch 0, Train Loss: 0.6893, Val Loss: 0.6894, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 10, Train Loss: 0.6630, Val Loss: 0.6636, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 20, Train Loss: 0.6528, Val Loss: 0.6537, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 30, Train Loss: 0.6490, Val Loss: 0.6500, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 40, Train Loss: 0.6473, Val Loss: 0.6485, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 50, Train Loss: 0.6470, Val Loss: 0.6482, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 60, Train Loss: 0.6467, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 70, Train Loss: 0.6466, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 80, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 90, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
#
# Classification Report:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0       0.65      1.00      0.79       100
#            1       0.00      0.00      0.00        54
#
#     accuracy                           0.65       154
#    macro avg       0.32      0.50      0.39       154
# weighted avg       0.42      0.65      0.51       154

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns



# Activation Functions

# fonction ReLU
def relu(x):
    """
    ReLU activation: max(0, x)
    """
    assert isinstance(x, np.ndarray), "Input to ReLU must be a numpy array"
    result = np.maximum(0, x)
    assert np.all(result >= 0), "ReLU output must be non-negative"
    return result

# fonction relu_derivative
def relu_derivative(x):
    """
    Derivative of ReLU: 1 if x > 0, else 0
    """
    assert isinstance(x, np.ndarray), "Input to ReLU derivative must be a numpy array"
    result = np.where(x > 0, 1, 0)
    assert np.all((result == 0) | (result == 1)), "ReLU derivative must be 0 or 1"
    return result


# fonction sigmoid
def sigmoid(x):
    """
    Sigmoid activation: 1 / (1 + exp(-x))
    """
    assert isinstance(x, np.ndarray), "Input to sigmoid must be a numpy array"
    # Clip x to avoid overflow in exp(-x) for large negative x
    # and underflow (exp(-x) -> inf) for large positive x.
    # Also avoids log(0) in loss calculation later.
    clipped_x = np.clip(x, -500, 500)
    result = 1 / (1 + np.exp(-clipped_x))
    # Add small epsilon to avoid exact 0 or 1 for log calculation stability
    epsilon = 1e-15
    result = np.clip(result, epsilon, 1 - epsilon)
    assert np.all((result >= 0) & (result <= 1)), "Sigmoid output must be in [0, 1]"
    return result


# fonction sigmoid_derivative
def sigmoid_derivative(x):
    """
    Derivative of sigmoid: sigmoid(x) * (1 - sigmoid(x))
    """
    assert isinstance(x, np.ndarray), "Input to sigmoid derivative must be a numpy array"
    s = sigmoid(x)
    result = s * (1 - s)
    # The theoretical max is 0.25, but due to epsilon clipping in sigmoid, 
    # we might be slightly off. Check within a tolerance.
    assert np.all((result >= 0) & (result <= 0.25 + 1e-9)), "Sigmoid derivative must be in [0, 0.25]"
    return result



# Neural Network class
class NeuralNetwork:
    def __init__(self, layer_sizes, learning_rate=0.01, l2_lambda=0.01):
        """Initialize the neural network with given layer sizes, learning rate, and L2 regularization."""
        self.layer_sizes = layer_sizes
        self.learning_rate = learning_rate
        self.l2_lambda = l2_lambda
        self.weights = []
        self.biases = []
        np.random.seed(42)
        for i in range(len(layer_sizes) - 1):
            w = np.random.randn(layer_sizes[i], layer_sizes[i + 1]) * 0.01
            b = np.zeros((1, layer_sizes[i + 1]))
            self.weights.append(w)
            self.biases.append(b)

    def forward(self, X):
        """Forward propagation: compute activations for all layers."""
        self.activations = [X]
        self.z_values = []
        for i in range(len(self.weights) - 1):
            z = np.dot(self.activations[-1], self.weights[i]) + self.biases[i]
            self.z_values.append(z)
            self.activations.append(relu(z))
        z = np.dot(self.activations[-1], self.weights[-1]) + self.biases[-1]
        self.z_values.append(z)
        output = sigmoid(z)
        self.activations.append(output)
        return output

    def compute_loss(self, y_true, y_pred):
        """Binary Cross-Entropy loss with L2 regularization."""
        m = y_true.shape[0]
        y_pred = np.clip(y_pred, 1e-15, 1 - 1e-15)  # Avoid log(0)
        loss = -np.mean(y_true * np.log(y_pred) + (1 - y_true) * np.log(1 - y_pred))
        # Add L2 regularization
        l2_term = self.l2_lambda * sum(np.sum(w ** 2) for w in self.weights) / (2 * m)
        return loss + l2_term

    def compute_accuracy(self, y_true, y_pred):
        """Compute accuracy: proportion of correct predictions."""
        predictions = (y_pred >= 0.5).astype(int)
        return np.mean(predictions == y_true)

    def backward(self, X, y, outputs):
        """Backpropagation: compute gradients with L2 regularization."""
        m = X.shape[0]
        self.d_weights = [np.zeros_like(w) for w in self.weights]
        self.d_biases = [np.zeros_like(b) for b in self.biases]
        dZ = outputs - y
        self.d_weights[-1] = (np.dot(self.activations[-2].T, dZ) + self.l2_lambda * self.weights[-1]) / m
        self.d_biases[-1] = np.sum(dZ, axis=0, keepdims=True) / m
        for i in range(len(self.weights) - 2, -1, -1):
            dA = np.dot(dZ, self.weights[i + 1].T)
            dZ = dA * relu_derivative(self.z_values[i])
            self.d_weights[i] = (np.dot(self.activations[i].T, dZ) + self.l2_lambda * self.weights[i]) / m
            self.d_biases[i] = np.sum(dZ, axis=0, keepdims=True) / m
        for i in range(len(self.weights)):
            self.weights[i] -= self.learning_rate * self.d_weights[i]
            self.biases[i] -= self.learning_rate * self.d_biases[i]

    def train(self, X, y, X_val, y_val, epochs, batch_size):
        """Train the neural network using mini-batch SGD with validation."""
        train_losses = []
        val_losses = []
        train_accuracies = []
        val_accuracies = []
        for epoch in range(epochs):
            indices = np.random.permutation(X.shape[0])
            X_shuffled = X[indices]
            y_shuffled = y[indices]
            epoch_loss = 0
            for i in range(0, X.shape[0], batch_size):
                X_batch = X_shuffled[i:i + batch_size]
                y_batch = y_shuffled[i:i + batch_size]
                outputs = self.forward(X_batch)
                epoch_loss += self.compute_loss(y_batch, outputs)
                self.backward(X_batch, y_batch, outputs)
            epoch_loss /= (X.shape[0] / batch_size)
            train_loss = self.compute_loss(y, self.forward(X))
            val_loss = self.compute_loss(y_val, self.forward(X_val))
            train_accuracy = self.compute_accuracy(y, self.forward(X))
            val_accuracy = self.compute_accuracy(y_val, self.forward(X_val))
            train_losses.append(train_loss)
            val_losses.append(val_loss)
            train_accuracies.append(train_accuracy)
            val_accuracies.append(val_accuracy)
            if epoch % 10 == 0:
                print(f"Epoch {epoch}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, Train Acc: {train_accuracy:.4f}, Val Acc: {val_accuracy:.4f}")
        return train_losses, val_losses, train_accuracies, val_accuracies

    def predict(self, X):
        """Predict class labels (0 or 1)."""
        outputs = self.forward(X)
        return (outputs >= 0.5).astype(int)

# Data preprocessing and training

# Load dataset
data = pd.read_csv('diabetes.csv')

# Replace invalid zeros with median
for col in ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']:
    data[col] = data[col].replace(0, data[col].median())

    
# Features and target
X = data.drop('Outcome', axis=1).values
y = data['Outcome'].values.reshape(-1, 1)

    
# Standardize features
X = (X - np.mean(X, axis=0)) / np.std(X, axis=0)
 
# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# Initialize and train model
nn = NeuralNetwork([X_train.shape[1], 16, 8, 1], learning_rate=0.01, l2_lambda=0.01)
train_losses, val_losses, train_accuracies, val_accuracies = nn.train(X_train, y_train, X_test, y_test, epochs=5000, batch_size=32)

# Evaluate
y_pred = nn.predict(X_test)
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
    # Confusion matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
    
# Loss and accuracy curves
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
ax1.plot(train_losses, label='Train Loss')
ax1.plot(val_losses, label='Validation Loss')
ax1.set_title('Loss Curves')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()
ax2.plot(train_accuracies, label='Train Accuracy')
ax2.plot(val_accuracies, label='Validation Accuracy')
ax2.set_title('Accuracy Curves')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.legend()
plt.show()
# Out:
# Epoch 0, Train Loss: 0.6893, Val Loss: 0.6894, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 10, Train Loss: 0.6630, Val Loss: 0.6636, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 20, Train Loss: 0.6528, Val Loss: 0.6537, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 30, Train Loss: 0.6490, Val Loss: 0.6500, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 40, Train Loss: 0.6473, Val Loss: 0.6485, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 50, Train Loss: 0.6470, Val Loss: 0.6482, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 60, Train Loss: 0.6467, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 70, Train Loss: 0.6466, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 80, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 90, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 100, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 110, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 120, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 130, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 140, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 150, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 160, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 170, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 180, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 190, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 200, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 210, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 220, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 230, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 240, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 250, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 260, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 270, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 280, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 290, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 300, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 310, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 320, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 330, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 340, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 350, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 360, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 370, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 380, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 390, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 400, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 410, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 420, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 430, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 440, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 450, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 460, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 470, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 480, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 490, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 500, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 510, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 520, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 530, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 540, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 550, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 560, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 570, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 580, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 590, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 600, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 610, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 620, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 630, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 640, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 650, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 660, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 670, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 680, Train Loss: 0.6465, Val Loss: 0.6479, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 690, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 700, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 710, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 720, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 730, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 740, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 750, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 760, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 770, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 780, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 790, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 800, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 810, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 820, Train Loss: 0.6465, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 830, Train Loss: 0.6464, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 840, Train Loss: 0.6464, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 850, Train Loss: 0.6464, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 860, Train Loss: 0.6464, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 870, Train Loss: 0.6464, Val Loss: 0.6478, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 880, Train Loss: 0.6464, Val Loss: 0.6477, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 890, Train Loss: 0.6464, Val Loss: 0.6477, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 900, Train Loss: 0.6463, Val Loss: 0.6477, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 910, Train Loss: 0.6463, Val Loss: 0.6477, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 920, Train Loss: 0.6463, Val Loss: 0.6477, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 930, Train Loss: 0.6462, Val Loss: 0.6476, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 940, Train Loss: 0.6462, Val Loss: 0.6476, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 950, Train Loss: 0.6462, Val Loss: 0.6476, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 960, Train Loss: 0.6461, Val Loss: 0.6475, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 970, Train Loss: 0.6460, Val Loss: 0.6474, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 980, Train Loss: 0.6459, Val Loss: 0.6474, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 990, Train Loss: 0.6458, Val Loss: 0.6473, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 1000, Train Loss: 0.6457, Val Loss: 0.6471, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 1010, Train Loss: 0.6455, Val Loss: 0.6470, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 1020, Train Loss: 0.6452, Val Loss: 0.6468, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 1030, Train Loss: 0.6449, Val Loss: 0.6465, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 1040, Train Loss: 0.6444, Val Loss: 0.6461, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 1050, Train Loss: 0.6438, Val Loss: 0.6456, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 1060, Train Loss: 0.6429, Val Loss: 0.6449, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 1070, Train Loss: 0.6416, Val Loss: 0.6438, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 1080, Train Loss: 0.6398, Val Loss: 0.6423, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 1090, Train Loss: 0.6368, Val Loss: 0.6398, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 1100, Train Loss: 0.6320, Val Loss: 0.6358, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 1110, Train Loss: 0.6239, Val Loss: 0.6291, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 1120, Train Loss: 0.6103, Val Loss: 0.6182, Train Acc: 0.6515, Val Acc: 0.6494
# Epoch 1130, Train Loss: 0.5874, Val Loss: 0.6002, Train Acc: 0.6498, Val Acc: 0.6558
# Epoch 1140, Train Loss: 0.5534, Val Loss: 0.5751, Train Acc: 0.7345, Val Acc: 0.7013
# Epoch 1150, Train Loss: 0.5166, Val Loss: 0.5511, Train Acc: 0.7720, Val Acc: 0.7208
# Epoch 1160, Train Loss: 0.4891, Val Loss: 0.5363, Train Acc: 0.7752, Val Acc: 0.7273
# Epoch 1170, Train Loss: 0.4718, Val Loss: 0.5306, Train Acc: 0.7801, Val Acc: 0.7143
# Epoch 1180, Train Loss: 0.4614, Val Loss: 0.5281, Train Acc: 0.7850, Val Acc: 0.7143
# Epoch 1190, Train Loss: 0.4551, Val Loss: 0.5252, Train Acc: 0.7915, Val Acc: 0.6948
# Epoch 1200, Train Loss: 0.4503, Val Loss: 0.5248, Train Acc: 0.7932, Val Acc: 0.6883
# Epoch 1210, Train Loss: 0.4467, Val Loss: 0.5233, Train Acc: 0.7850, Val Acc: 0.6883
# Epoch 1220, Train Loss: 0.4442, Val Loss: 0.5244, Train Acc: 0.7866, Val Acc: 0.7013
# Epoch 1230, Train Loss: 0.4422, Val Loss: 0.5228, Train Acc: 0.7932, Val Acc: 0.6948
# Epoch 1240, Train Loss: 0.4405, Val Loss: 0.5242, Train Acc: 0.7948, Val Acc: 0.6948
# Epoch 1250, Train Loss: 0.4393, Val Loss: 0.5242, Train Acc: 0.7932, Val Acc: 0.7013
# Epoch 1260, Train Loss: 0.4382, Val Loss: 0.5239, Train Acc: 0.7899, Val Acc: 0.6948
# Epoch 1270, Train Loss: 0.4372, Val Loss: 0.5236, Train Acc: 0.7899, Val Acc: 0.6948
# Epoch 1280, Train Loss: 0.4364, Val Loss: 0.5249, Train Acc: 0.7883, Val Acc: 0.7013
# Epoch 1290, Train Loss: 0.4354, Val Loss: 0.5253, Train Acc: 0.7850, Val Acc: 0.6948
# Epoch 1300, Train Loss: 0.4346, Val Loss: 0.5248, Train Acc: 0.7834, Val Acc: 0.7013
# Epoch 1310, Train Loss: 0.4337, Val Loss: 0.5241, Train Acc: 0.7883, Val Acc: 0.6948
# Epoch 1320, Train Loss: 0.4328, Val Loss: 0.5243, Train Acc: 0.7850, Val Acc: 0.6948
# Epoch 1330, Train Loss: 0.4320, Val Loss: 0.5268, Train Acc: 0.7834, Val Acc: 0.6948
# Epoch 1340, Train Loss: 0.4312, Val Loss: 0.5282, Train Acc: 0.7850, Val Acc: 0.6948
# Epoch 1350, Train Loss: 0.4305, Val Loss: 0.5295, Train Acc: 0.7866, Val Acc: 0.6948
# Epoch 1360, Train Loss: 0.4299, Val Loss: 0.5270, Train Acc: 0.7866, Val Acc: 0.6948
# Epoch 1370, Train Loss: 0.4293, Val Loss: 0.5288, Train Acc: 0.7850, Val Acc: 0.7013
# Epoch 1380, Train Loss: 0.4286, Val Loss: 0.5310, Train Acc: 0.7883, Val Acc: 0.6948
# Epoch 1390, Train Loss: 0.4279, Val Loss: 0.5293, Train Acc: 0.7866, Val Acc: 0.6948
# Epoch 1400, Train Loss: 0.4271, Val Loss: 0.5305, Train Acc: 0.7866, Val Acc: 0.7013
# Epoch 1410, Train Loss: 0.4267, Val Loss: 0.5280, Train Acc: 0.7850, Val Acc: 0.6948
# Epoch 1420, Train Loss: 0.4259, Val Loss: 0.5289, Train Acc: 0.7866, Val Acc: 0.7013
# Epoch 1430, Train Loss: 0.4252, Val Loss: 0.5289, Train Acc: 0.7850, Val Acc: 0.7013
# Epoch 1440, Train Loss: 0.4246, Val Loss: 0.5287, Train Acc: 0.7915, Val Acc: 0.7013
# Epoch 1450, Train Loss: 0.4240, Val Loss: 0.5287, Train Acc: 0.7883, Val Acc: 0.7078
# Epoch 1460, Train Loss: 0.4235, Val Loss: 0.5294, Train Acc: 0.7883, Val Acc: 0.7013
# Epoch 1470, Train Loss: 0.4229, Val Loss: 0.5315, Train Acc: 0.7899, Val Acc: 0.6948
# Epoch 1480, Train Loss: 0.4224, Val Loss: 0.5320, Train Acc: 0.7899, Val Acc: 0.6948
# Epoch 1490, Train Loss: 0.4218, Val Loss: 0.5289, Train Acc: 0.7948, Val Acc: 0.7013
# Epoch 1500, Train Loss: 0.4212, Val Loss: 0.5243, Train Acc: 0.7899, Val Acc: 0.7013
# Epoch 1510, Train Loss: 0.4204, Val Loss: 0.5270, Train Acc: 0.7899, Val Acc: 0.6948
# Epoch 1520, Train Loss: 0.4198, Val Loss: 0.5272, Train Acc: 0.7915, Val Acc: 0.6948
# Epoch 1530, Train Loss: 0.4191, Val Loss: 0.5277, Train Acc: 0.7948, Val Acc: 0.7013
# Epoch 1540, Train Loss: 0.4184, Val Loss: 0.5280, Train Acc: 0.7915, Val Acc: 0.6948
# Epoch 1550, Train Loss: 0.4177, Val Loss: 0.5309, Train Acc: 0.7964, Val Acc: 0.6883
# Epoch 1560, Train Loss: 0.4168, Val Loss: 0.5277, Train Acc: 0.7948, Val Acc: 0.6883
# Epoch 1570, Train Loss: 0.4161, Val Loss: 0.5282, Train Acc: 0.7948, Val Acc: 0.6883
# Epoch 1580, Train Loss: 0.4151, Val Loss: 0.5280, Train Acc: 0.7948, Val Acc: 0.6883
# Epoch 1590, Train Loss: 0.4145, Val Loss: 0.5284, Train Acc: 0.7964, Val Acc: 0.6818
# Epoch 1600, Train Loss: 0.4137, Val Loss: 0.5260, Train Acc: 0.7964, Val Acc: 0.6818
# Epoch 1610, Train Loss: 0.4127, Val Loss: 0.5266, Train Acc: 0.8029, Val Acc: 0.6948
# Epoch 1620, Train Loss: 0.4117, Val Loss: 0.5255, Train Acc: 0.8013, Val Acc: 0.6948
# Epoch 1630, Train Loss: 0.4109, Val Loss: 0.5264, Train Acc: 0.7980, Val Acc: 0.6818
# Epoch 1640, Train Loss: 0.4101, Val Loss: 0.5233, Train Acc: 0.7997, Val Acc: 0.6883
# Epoch 1650, Train Loss: 0.4093, Val Loss: 0.5272, Train Acc: 0.8013, Val Acc: 0.6948
# Epoch 1660, Train Loss: 0.4085, Val Loss: 0.5276, Train Acc: 0.8013, Val Acc: 0.7013
# Epoch 1670, Train Loss: 0.4079, Val Loss: 0.5262, Train Acc: 0.8029, Val Acc: 0.6883
# Epoch 1680, Train Loss: 0.4071, Val Loss: 0.5309, Train Acc: 0.8046, Val Acc: 0.6883
# Epoch 1690, Train Loss: 0.4064, Val Loss: 0.5306, Train Acc: 0.8046, Val Acc: 0.6883
# Epoch 1700, Train Loss: 0.4057, Val Loss: 0.5308, Train Acc: 0.8094, Val Acc: 0.6948
# Epoch 1710, Train Loss: 0.4051, Val Loss: 0.5322, Train Acc: 0.8094, Val Acc: 0.6883
# Epoch 1720, Train Loss: 0.4044, Val Loss: 0.5318, Train Acc: 0.8176, Val Acc: 0.7078
# Epoch 1730, Train Loss: 0.4037, Val Loss: 0.5336, Train Acc: 0.8143, Val Acc: 0.7013
# Epoch 1740, Train Loss: 0.4031, Val Loss: 0.5349, Train Acc: 0.8176, Val Acc: 0.7013
# Epoch 1750, Train Loss: 0.4025, Val Loss: 0.5369, Train Acc: 0.8127, Val Acc: 0.7013
# Epoch 1760, Train Loss: 0.4020, Val Loss: 0.5364, Train Acc: 0.8143, Val Acc: 0.7078
# Epoch 1770, Train Loss: 0.4015, Val Loss: 0.5324, Train Acc: 0.8127, Val Acc: 0.7078
# Epoch 1780, Train Loss: 0.4008, Val Loss: 0.5315, Train Acc: 0.8192, Val Acc: 0.7078
# Epoch 1790, Train Loss: 0.4001, Val Loss: 0.5343, Train Acc: 0.8176, Val Acc: 0.7078
# Epoch 1800, Train Loss: 0.3994, Val Loss: 0.5319, Train Acc: 0.8208, Val Acc: 0.7143
# Epoch 1810, Train Loss: 0.3987, Val Loss: 0.5333, Train Acc: 0.8176, Val Acc: 0.7078
# Epoch 1820, Train Loss: 0.3982, Val Loss: 0.5334, Train Acc: 0.8192, Val Acc: 0.7078
# Epoch 1830, Train Loss: 0.3972, Val Loss: 0.5294, Train Acc: 0.8143, Val Acc: 0.7208
# Epoch 1840, Train Loss: 0.3966, Val Loss: 0.5318, Train Acc: 0.8225, Val Acc: 0.7208
# Epoch 1850, Train Loss: 0.3963, Val Loss: 0.5329, Train Acc: 0.8192, Val Acc: 0.7273
# Epoch 1860, Train Loss: 0.3954, Val Loss: 0.5359, Train Acc: 0.8192, Val Acc: 0.7273
# Epoch 1870, Train Loss: 0.3947, Val Loss: 0.5362, Train Acc: 0.8160, Val Acc: 0.7208
# Epoch 1880, Train Loss: 0.3941, Val Loss: 0.5335, Train Acc: 0.8208, Val Acc: 0.7273
# Epoch 1890, Train Loss: 0.3934, Val Loss: 0.5358, Train Acc: 0.8225, Val Acc: 0.7143
# Epoch 1900, Train Loss: 0.3929, Val Loss: 0.5369, Train Acc: 0.8176, Val Acc: 0.7338
# Epoch 1910, Train Loss: 0.3924, Val Loss: 0.5350, Train Acc: 0.8192, Val Acc: 0.7208
# Epoch 1920, Train Loss: 0.3919, Val Loss: 0.5344, Train Acc: 0.8160, Val Acc: 0.7208
# Epoch 1930, Train Loss: 0.3912, Val Loss: 0.5388, Train Acc: 0.8192, Val Acc: 0.7078
# Epoch 1940, Train Loss: 0.3905, Val Loss: 0.5387, Train Acc: 0.8208, Val Acc: 0.7208
# Epoch 1950, Train Loss: 0.3899, Val Loss: 0.5436, Train Acc: 0.8208, Val Acc: 0.7273
# Epoch 1960, Train Loss: 0.3895, Val Loss: 0.5354, Train Acc: 0.8176, Val Acc: 0.7273
# Epoch 1970, Train Loss: 0.3890, Val Loss: 0.5412, Train Acc: 0.8160, Val Acc: 0.7208
# Epoch 1980, Train Loss: 0.3883, Val Loss: 0.5398, Train Acc: 0.8160, Val Acc: 0.7208
# Epoch 1990, Train Loss: 0.3875, Val Loss: 0.5416, Train Acc: 0.8160, Val Acc: 0.7273
# Epoch 2000, Train Loss: 0.3872, Val Loss: 0.5391, Train Acc: 0.8176, Val Acc: 0.7273
# Epoch 2010, Train Loss: 0.3866, Val Loss: 0.5405, Train Acc: 0.8225, Val Acc: 0.7143
# Epoch 2020, Train Loss: 0.3859, Val Loss: 0.5401, Train Acc: 0.8094, Val Acc: 0.7208
# Epoch 2030, Train Loss: 0.3852, Val Loss: 0.5408, Train Acc: 0.8192, Val Acc: 0.7208
# Epoch 2040, Train Loss: 0.3844, Val Loss: 0.5360, Train Acc: 0.8176, Val Acc: 0.7078
# Epoch 2050, Train Loss: 0.3838, Val Loss: 0.5447, Train Acc: 0.8143, Val Acc: 0.7013
# Epoch 2060, Train Loss: 0.3827, Val Loss: 0.5422, Train Acc: 0.8192, Val Acc: 0.7208
# Epoch 2070, Train Loss: 0.3822, Val Loss: 0.5435, Train Acc: 0.8257, Val Acc: 0.7273
# Epoch 2080, Train Loss: 0.3817, Val Loss: 0.5463, Train Acc: 0.8160, Val Acc: 0.7143
# Epoch 2090, Train Loss: 0.3810, Val Loss: 0.5440, Train Acc: 0.8241, Val Acc: 0.7078
# Epoch 2100, Train Loss: 0.3802, Val Loss: 0.5469, Train Acc: 0.8225, Val Acc: 0.7208
# Epoch 2110, Train Loss: 0.3795, Val Loss: 0.5478, Train Acc: 0.8208, Val Acc: 0.7078
# Epoch 2120, Train Loss: 0.3789, Val Loss: 0.5444, Train Acc: 0.8257, Val Acc: 0.7208
# Epoch 2130, Train Loss: 0.3778, Val Loss: 0.5488, Train Acc: 0.8225, Val Acc: 0.7078
# Epoch 2140, Train Loss: 0.3773, Val Loss: 0.5437, Train Acc: 0.8290, Val Acc: 0.7273
# Epoch 2150, Train Loss: 0.3771, Val Loss: 0.5499, Train Acc: 0.8290, Val Acc: 0.7208
# Epoch 2160, Train Loss: 0.3758, Val Loss: 0.5520, Train Acc: 0.8306, Val Acc: 0.7013
# Epoch 2170, Train Loss: 0.3759, Val Loss: 0.5497, Train Acc: 0.8290, Val Acc: 0.7273
# Epoch 2180, Train Loss: 0.3752, Val Loss: 0.5519, Train Acc: 0.8339, Val Acc: 0.7338
# Epoch 2190, Train Loss: 0.3742, Val Loss: 0.5507, Train Acc: 0.8274, Val Acc: 0.7143
# Epoch 2200, Train Loss: 0.3733, Val Loss: 0.5512, Train Acc: 0.8290, Val Acc: 0.7273
# Epoch 2210, Train Loss: 0.3730, Val Loss: 0.5489, Train Acc: 0.8339, Val Acc: 0.7338
# Epoch 2220, Train Loss: 0.3723, Val Loss: 0.5496, Train Acc: 0.8306, Val Acc: 0.7338
# Epoch 2230, Train Loss: 0.3721, Val Loss: 0.5595, Train Acc: 0.8322, Val Acc: 0.7338
# Epoch 2240, Train Loss: 0.3711, Val Loss: 0.5543, Train Acc: 0.8322, Val Acc: 0.7338
# Epoch 2250, Train Loss: 0.3703, Val Loss: 0.5546, Train Acc: 0.8322, Val Acc: 0.7403
# Epoch 2260, Train Loss: 0.3708, Val Loss: 0.5530, Train Acc: 0.8241, Val Acc: 0.7208
# Epoch 2270, Train Loss: 0.3695, Val Loss: 0.5534, Train Acc: 0.8306, Val Acc: 0.7403
# Epoch 2280, Train Loss: 0.3690, Val Loss: 0.5556, Train Acc: 0.8388, Val Acc: 0.7338
# Epoch 2290, Train Loss: 0.3685, Val Loss: 0.5549, Train Acc: 0.8388, Val Acc: 0.7403
# Epoch 2300, Train Loss: 0.3679, Val Loss: 0.5518, Train Acc: 0.8306, Val Acc: 0.7403
# Epoch 2310, Train Loss: 0.3684, Val Loss: 0.5577, Train Acc: 0.8339, Val Acc: 0.7403
# Epoch 2320, Train Loss: 0.3665, Val Loss: 0.5547, Train Acc: 0.8322, Val Acc: 0.7338
# Epoch 2330, Train Loss: 0.3662, Val Loss: 0.5587, Train Acc: 0.8339, Val Acc: 0.7273
# Epoch 2340, Train Loss: 0.3667, Val Loss: 0.5562, Train Acc: 0.8355, Val Acc: 0.7338
# Epoch 2350, Train Loss: 0.3648, Val Loss: 0.5597, Train Acc: 0.8371, Val Acc: 0.7338
# Epoch 2360, Train Loss: 0.3639, Val Loss: 0.5596, Train Acc: 0.8420, Val Acc: 0.7338
# Epoch 2370, Train Loss: 0.3634, Val Loss: 0.5578, Train Acc: 0.8436, Val Acc: 0.7468
# Epoch 2380, Train Loss: 0.3624, Val Loss: 0.5644, Train Acc: 0.8420, Val Acc: 0.7403
# Epoch 2390, Train Loss: 0.3623, Val Loss: 0.5598, Train Acc: 0.8436, Val Acc: 0.7338
# Epoch 2400, Train Loss: 0.3612, Val Loss: 0.5576, Train Acc: 0.8453, Val Acc: 0.7338
# Epoch 2410, Train Loss: 0.3613, Val Loss: 0.5586, Train Acc: 0.8404, Val Acc: 0.7338
# Epoch 2420, Train Loss: 0.3604, Val Loss: 0.5634, Train Acc: 0.8322, Val Acc: 0.7403
# Epoch 2430, Train Loss: 0.3594, Val Loss: 0.5589, Train Acc: 0.8453, Val Acc: 0.7403
# Epoch 2440, Train Loss: 0.3596, Val Loss: 0.5662, Train Acc: 0.8404, Val Acc: 0.7338
# Epoch 2450, Train Loss: 0.3606, Val Loss: 0.5511, Train Acc: 0.8404, Val Acc: 0.7403
# Epoch 2460, Train Loss: 0.3577, Val Loss: 0.5708, Train Acc: 0.8436, Val Acc: 0.7403
# Epoch 2470, Train Loss: 0.3571, Val Loss: 0.5661, Train Acc: 0.8469, Val Acc: 0.7468
# Epoch 2480, Train Loss: 0.3574, Val Loss: 0.5745, Train Acc: 0.8502, Val Acc: 0.7468
# Epoch 2490, Train Loss: 0.3558, Val Loss: 0.5653, Train Acc: 0.8469, Val Acc: 0.7468
# Epoch 2500, Train Loss: 0.3555, Val Loss: 0.5681, Train Acc: 0.8371, Val Acc: 0.7468
# Epoch 2510, Train Loss: 0.3549, Val Loss: 0.5711, Train Acc: 0.8485, Val Acc: 0.7403
# Epoch 2520, Train Loss: 0.3537, Val Loss: 0.5776, Train Acc: 0.8436, Val Acc: 0.7403
# Epoch 2530, Train Loss: 0.3524, Val Loss: 0.5731, Train Acc: 0.8518, Val Acc: 0.7468
# Epoch 2540, Train Loss: 0.3518, Val Loss: 0.5745, Train Acc: 0.8502, Val Acc: 0.7468
# Epoch 2550, Train Loss: 0.3515, Val Loss: 0.5754, Train Acc: 0.8502, Val Acc: 0.7468
# Epoch 2560, Train Loss: 0.3507, Val Loss: 0.5662, Train Acc: 0.8534, Val Acc: 0.7468
# Epoch 2570, Train Loss: 0.3499, Val Loss: 0.5639, Train Acc: 0.8453, Val Acc: 0.7468
# Epoch 2580, Train Loss: 0.3511, Val Loss: 0.5700, Train Acc: 0.8502, Val Acc: 0.7403
# Epoch 2590, Train Loss: 0.3499, Val Loss: 0.5738, Train Acc: 0.8616, Val Acc: 0.7468
# Epoch 2600, Train Loss: 0.3474, Val Loss: 0.5717, Train Acc: 0.8583, Val Acc: 0.7338
# Epoch 2610, Train Loss: 0.3461, Val Loss: 0.5748, Train Acc: 0.8534, Val Acc: 0.7468
# Epoch 2620, Train Loss: 0.3452, Val Loss: 0.5740, Train Acc: 0.8518, Val Acc: 0.7532
# Epoch 2630, Train Loss: 0.3467, Val Loss: 0.5792, Train Acc: 0.8550, Val Acc: 0.7468
# Epoch 2640, Train Loss: 0.3453, Val Loss: 0.5658, Train Acc: 0.8485, Val Acc: 0.7468
# Epoch 2650, Train Loss: 0.3439, Val Loss: 0.5655, Train Acc: 0.8599, Val Acc: 0.7468
# Epoch 2660, Train Loss: 0.3420, Val Loss: 0.5735, Train Acc: 0.8599, Val Acc: 0.7273
# Epoch 2670, Train Loss: 0.3405, Val Loss: 0.5804, Train Acc: 0.8534, Val Acc: 0.7403
# Epoch 2680, Train Loss: 0.3396, Val Loss: 0.5805, Train Acc: 0.8550, Val Acc: 0.7468
# Epoch 2690, Train Loss: 0.3402, Val Loss: 0.5684, Train Acc: 0.8599, Val Acc: 0.7403
# Epoch 2700, Train Loss: 0.3420, Val Loss: 0.5748, Train Acc: 0.8534, Val Acc: 0.7468
# Epoch 2710, Train Loss: 0.3375, Val Loss: 0.5826, Train Acc: 0.8583, Val Acc: 0.7403
# Epoch 2720, Train Loss: 0.3377, Val Loss: 0.5848, Train Acc: 0.8534, Val Acc: 0.7468
# Epoch 2730, Train Loss: 0.3376, Val Loss: 0.5784, Train Acc: 0.8534, Val Acc: 0.7403
# Epoch 2740, Train Loss: 0.3394, Val Loss: 0.5840, Train Acc: 0.8518, Val Acc: 0.7208
# Epoch 2750, Train Loss: 0.3393, Val Loss: 0.5978, Train Acc: 0.8567, Val Acc: 0.7338
